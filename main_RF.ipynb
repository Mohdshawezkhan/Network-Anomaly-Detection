# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# %%
Net_data_Vnew=pd.read_csv("Train.txt",sep=",",names=["duration","protocoltype","service","flag","srcbytes","dstbytes","land", "wrongfragment","urgent","hot","numfailedlogins","loggedin", "numcompromised","rootshell","suattempted","numroot","numfilecreations", "numshells","numaccessfiles","numoutboundcmds","ishostlogin",
"isguestlogin","count","srvcount","serrorrate", "srvserrorrate",
"rerrorrate","srvrerrorrate","samesrvrate", "diffsrvrate", "srvdiffhostrate","dsthostcount","dsthostsrvcount","dsthostsamesrvrate", "dsthostdiffsrvrate","dsthostsamesrcportrate",
"dsthostsrvdiffhostrate","dsthostserrorrate","dsthostsrvserrorrate",
"dsthostrerrorrate","dsthostsrvrerrorrate","attack", "lastflag"])
Net_data_Vnew.head()
# Out:
#    duration protocoltype   service flag  srcbytes  dstbytes  land  \
# 0         0          tcp  ftp_data   SF       491         0     0
# 1         0          udp     other   SF       146         0     0
# 2         0          tcp   private   S0         0         0     0
# 3         0          tcp      http   SF       232      8153     0
# 4         0          tcp      http   SF       199       420     0
#
#    wrongfragment  urgent  hot  ...  dsthostsamesrvrate  dsthostdiffsrvrate  \
# 0              0       0    0  ...                0.17                0.03
# 1              0       0    0  ...                0.00                0.60
# 2              0       0    0  ...                0.10                0.05
# 3              0       0    0  ...                1.00                0.00
# 4              0       0    0  ...                1.00                0.00
#
#    dsthostsamesrcportrate  dsthostsrvdiffhostrate  dsthostserrorrate  \
# 0                    0.17                    0.00               0.00
# 1                    0.88                    0.00               0.00
# 2                    0.00                    0.00               1.00
# 3                    0.03                    0.04               0.03
# 4                    0.00                    0.00               0.00
#
#    dsthostsrvserrorrate  dsthostrerrorrate  dsthostsrvrerrorrate   attack  \
# 0                  0.00               0.05                  0.00   normal
# 1                  0.00               0.00                  0.00   normal
# 2                  1.00               0.00                  0.00  neptune
# 3                  0.01               0.00                  0.01   normal
# 4                  0.00               0.00                  0.00   normal
#
#    lastflag
# 0        20
# 1        15
# 2        19
# 3        21
# 4        21
#
# [5 rows x 43 columns]

# %%
Net_data_test=pd.read_csv("Test.txt",sep=",",names=["duration","protocoltype","service","flag","srcbytes","dstbytes","land", "wrongfragment","urgent","hot","numfailedlogins","loggedin", "numcompromised","rootshell","suattempted","numroot","numfilecreations", "numshells","numaccessfiles","numoutboundcmds","ishostlogin",
"isguestlogin","count","srvcount","serrorrate", "srvserrorrate",
"rerrorrate","srvrerrorrate","samesrvrate", "diffsrvrate", "srvdiffhostrate","dsthostcount","dsthostsrvcount","dsthostsamesrvrate", "dsthostdiffsrvrate","dsthostsamesrcportrate",
"dsthostsrvdiffhostrate","dsthostserrorrate","dsthostsrvserrorrate",
"dsthostrerrorrate","dsthostsrvrerrorrate","attack", "lastflag"])
Net_data_test.head()
# Out:
#    duration protocoltype   service  flag  srcbytes  dstbytes  land  \
# 0         0          tcp   private   REJ         0         0     0
# 1         0          tcp   private   REJ         0         0     0
# 2         2          tcp  ftp_data    SF     12983         0     0
# 3         0         icmp     eco_i    SF        20         0     0
# 4         1          tcp    telnet  RSTO         0        15     0
#
#    wrongfragment  urgent  hot  ...  dsthostsamesrvrate  dsthostdiffsrvrate  \
# 0              0       0    0  ...                0.04                0.06
# 1              0       0    0  ...                0.00                0.06
# 2              0       0    0  ...                0.61                0.04
# 3              0       0    0  ...                1.00                0.00
# 4              0       0    0  ...                0.31                0.17
#
#    dsthostsamesrcportrate  dsthostsrvdiffhostrate  dsthostserrorrate  \
# 0                    0.00                    0.00                0.0
# 1                    0.00                    0.00                0.0
# 2                    0.61                    0.02                0.0
# 3                    1.00                    0.28                0.0
# 4                    0.03                    0.02                0.0
#
#    dsthostsrvserrorrate  dsthostrerrorrate  dsthostsrvrerrorrate   attack  \
# 0                   0.0               1.00                  1.00  neptune
# 1                   0.0               1.00                  1.00  neptune
# 2                   0.0               0.00                  0.00   normal
# 3                   0.0               0.00                  0.00    saint
# 4                   0.0               0.83                  0.71    mscan
#
#    lastflag
# 0        21
# 1        21
# 2        21
# 3        15
# 4        11
#
# [5 rows x 43 columns]

# %%
Net_data=pd.concat([Net_data_Vnew, Net_data_test], ignore_index=True)

# %%
Net_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148517 entries, 0 to 148516
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   duration                148517 non-null  int64
#  1   protocoltype            148517 non-null  object
#  2   service                 148517 non-null  object
#  3   flag                    148517 non-null  object
#  4   srcbytes                148517 non-null  int64
#  5   dstbytes                148517 non-null  int64
#  6   land                    148517 non-null  int64
#  7   wrongfragment           148517 non-null  int64
#  8   urgent                  148517 non-null  int64
#  9   hot                     148517 non-null  int64
#  10  numfailedlogins         148517 non-null  int64
#  11  loggedin                148517 non-null  int64
#  12  numcompromised          148517 non-null  int64
#  13  rootshell               148517 non-null  int64
#  14  suattempted             148517 non-null  int64
#  15  numroot                 148517 non-null  int64
#  16  numfilecreations        148517 non-null  int64
#  17  numshells               148517 non-null  int64
#  18  numaccessfiles          148517 non-null  int64
#  19  numoutboundcmds         148517 non-null  int64
#  20  ishostlogin             148517 non-null  int64
#  21  isguestlogin            148517 non-null  int64
#  22  count                   148517 non-null  int64
#  23  srvcount                148517 non-null  int64
#  24  serrorrate              148517 non-null  float64
#  25  srvserrorrate           148517 non-null  float64
#  26  rerrorrate              148517 non-null  float64
#  27  srvrerrorrate           148517 non-null  float64
#  28  samesrvrate             148517 non-null  float64
#  29  diffsrvrate             148517 non-null  float64
#  30  srvdiffhostrate         148517 non-null  float64
#  31  dsthostcount            148517 non-null  int64
#  32  dsthostsrvcount         148517 non-null  int64
#  33  dsthostsamesrvrate      148517 non-null  float64
#  34  dsthostdiffsrvrate      148517 non-null  float64
#  35  dsthostsamesrcportrate  148517 non-null  float64
#  36  dsthostsrvdiffhostrate  148517 non-null  float64
#  37  dsthostserrorrate       148517 non-null  float64
#  38  dsthostsrvserrorrate    148517 non-null  float64
#  39  dsthostrerrorrate       148517 non-null  float64
#  40  dsthostsrvrerrorrate    148517 non-null  float64
#  41  attack                  148517 non-null  object
#  42  lastflag                148517 non-null  int64
# dtypes: float64(15), int64(24), object(4)
# memory usage: 48.7+ MB

# %%
Net_data.shape
# Out:
# (148517, 43)

# %%
Net_data.describe()
# Out:
#             duration      srcbytes      dstbytes           land  \
# count  148517.000000  1.485170e+05  1.485170e+05  148517.000000
# mean      276.779305  4.022795e+04  1.708885e+04       0.000215
# std      2460.683131  5.409612e+06  3.703525e+06       0.014677
# min         0.000000  0.000000e+00  0.000000e+00       0.000000
# 25%         0.000000  0.000000e+00  0.000000e+00       0.000000
# 50%         0.000000  4.400000e+01  0.000000e+00       0.000000
# 75%         0.000000  2.780000e+02  5.710000e+02       0.000000
# max     57715.000000  1.379964e+09  1.309937e+09       1.000000
#
#        wrongfragment         urgent            hot  numfailedlogins  \
# count  148517.000000  148517.000000  148517.000000    148517.000000
# mean        0.020523       0.000202       0.189379         0.004323
# std         0.240069       0.019417       2.013160         0.072248
# min         0.000000       0.000000       0.000000         0.000000
# 25%         0.000000       0.000000       0.000000         0.000000
# 50%         0.000000       0.000000       0.000000         0.000000
# 75%         0.000000       0.000000       0.000000         0.000000
# max         3.000000       3.000000     101.000000         5.000000
#
#             loggedin  numcompromised  ...  dsthostsrvcount  \
# count  148517.000000   148517.000000  ...    148517.000000
# mean        0.402789        0.255062  ...       119.462661
# std         0.490461       22.231375  ...       111.232318
# min         0.000000        0.000000  ...         0.000000
# 25%         0.000000        0.000000  ...        11.000000
# 50%         0.000000        0.000000  ...        72.000000
# 75%         1.000000        0.000000  ...       255.000000
# max         1.000000     7479.000000  ...       255.000000
#
#        dsthostsamesrvrate  dsthostdiffsrvrate  dsthostsamesrcportrate  \
# count       148517.000000       148517.000000           148517.000000
# mean             0.534521            0.084103                0.145932
# std              0.448061            0.194102                0.308638
# min              0.000000            0.000000                0.000000
# 25%              0.050000            0.000000                0.000000
# 50%              0.600000            0.020000                0.000000
# 75%              1.000000            0.070000                0.050000
# max              1.000000            1.000000                1.000000
#
#        dsthostsrvdiffhostrate  dsthostserrorrate  dsthostsrvserrorrate  \
# count           148517.000000      148517.000000         148517.000000
# mean                 0.030584           0.256122              0.251304
# std                  0.108975           0.428500              0.429719
# min                  0.000000           0.000000              0.000000
# 25%                  0.000000           0.000000              0.000000
# 50%                  0.000000           0.000000              0.000000
# 75%                  0.010000           0.600000              0.500000
# max                  1.000000           1.000000              1.000000
#
#        dsthostrerrorrate  dsthostsrvrerrorrate       lastflag
# count      148517.000000         148517.000000  148517.000000
# mean            0.136220              0.136397      19.278480
# std             0.322741              0.335282       2.739757
# min             0.000000              0.000000       0.000000
# 25%             0.000000              0.000000      18.000000
# 50%             0.000000              0.000000      20.000000
# 75%             0.000000              0.000000      21.000000
# max             1.000000              1.000000      21.000000
#
# [8 rows x 39 columns]

# %%
Net_data.describe(include='O')
# Out:
#        protocoltype service    flag  attack
# count        148517  148517  148517  148517
# unique            3      70      11      40
# top             tcp    http      SF  normal
# freq         121569   48191   89820   77054

# %%
Net_data.columns
# Out:
# Index(['duration', 'protocoltype', 'service', 'flag', 'srcbytes', 'dstbytes',
#        'land', 'wrongfragment', 'urgent', 'hot', 'numfailedlogins', 'loggedin',
#        'numcompromised', 'rootshell', 'suattempted', 'numroot',
#        'numfilecreations', 'numshells', 'numaccessfiles', 'numoutboundcmds',
#        'ishostlogin', 'isguestlogin', 'count', 'srvcount', 'serrorrate',
#        'srvserrorrate', 'rerrorrate', 'srvrerrorrate', 'samesrvrate',
#        'diffsrvrate', 'srvdiffhostrate', 'dsthostcount', 'dsthostsrvcount',
#        'dsthostsamesrvrate', 'dsthostdiffsrvrate', 'dsthostsamesrcportrate',
#        'dsthostsrvdiffhostrate', 'dsthostserrorrate', 'dsthostsrvserrorrate',
#        'dsthostrerrorrate', 'dsthostsrvrerrorrate', 'attack', 'lastflag'],
#       dtype='object')

# %%
Net_data_new=Net_data[['duration', 'protocoltype', 'service', 'flag', 'srcbytes', 'dstbytes',
    'wrongfragment','hot', 'loggedin',
    'numcompromised', 'rootshell', 'suattempted', 'numroot',
    'numfilecreations', 'numshells', 'numaccessfiles',
    'isguestlogin', 'count', 'srvcount', 'serrorrate',
    'srvserrorrate', 'rerrorrate', 'srvrerrorrate', 'samesrvrate',
    'diffsrvrate', 'srvdiffhostrate', 'dsthostcount', 'dsthostsrvcount',
    'dsthostsamesrvrate', 'dsthostdiffsrvrate', 'dsthostsamesrcportrate',
    'dsthostsrvdiffhostrate', 'dsthostserrorrate', 'dsthostsrvserrorrate',
    'dsthostrerrorrate', 'dsthostsrvrerrorrate', 'attack', 'lastflag']].copy()

# %%
Net_data_new.isnull().sum()
# Out:
# duration                  0
# protocoltype              0
# service                   0
# flag                      0
# srcbytes                  0
# dstbytes                  0
# wrongfragment             0
# hot                       0
# loggedin                  0
# numcompromised            0
# rootshell                 0
# suattempted               0
# numroot                   0
# numfilecreations          0
# numshells                 0
# numaccessfiles            0
# isguestlogin              0
# count                     0
# srvcount                  0
# serrorrate                0
# srvserrorrate             0
# rerrorrate                0
# srvrerrorrate             0
# samesrvrate               0
# diffsrvrate               0
# srvdiffhostrate           0
# dsthostcount              0
# dsthostsrvcount           0
# dsthostsamesrvrate        0
# dsthostdiffsrvrate        0
# dsthostsamesrcportrate    0
# dsthostsrvdiffhostrate    0
# dsthostserrorrate         0
# dsthostsrvserrorrate      0
# dsthostrerrorrate         0
# dsthostsrvrerrorrate      0
# attack                    0
# lastflag                  0
# dtype: int64

# %%
Net_data_new.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148512    False
# 148513    False
# 148514    False
# 148515     True
# 148516    False
# Length: 148517, dtype: bool

# %%
Net_data_new.loc[Net_data_new.duplicated()]
# Out:
#         duration protocoltype   service flag  srcbytes  dstbytes  \
# 126081         0          tcp   private  REJ         0         0
# 126139         0          tcp   private   S0         0         0
# 126154         0          udp  domain_u   SF        44        44
# 126208         0         icmp     ecr_i   SF      1480         0
# 126214         0          udp  domain_u   SF        44        44
# ...          ...          ...       ...  ...       ...       ...
# 148440         0          tcp   private   S0         0         0
# 148458         0         icmp     ecr_i   SF      1032         0
# 148501         0         icmp     ecr_i   SF      1032         0
# 148511         0         icmp     ecr_i   SF      1032         0
# 148515         0          udp  domain_u   SF        42        42
#
#         wrongfragment  hot  loggedin  numcompromised  ...  dsthostsamesrvrate  \
# 126081              0    0         0               0  ...                0.04
# 126139              0    0         0               0  ...                0.03
# 126154              0    0         0               0  ...                1.00
# 126208              1    0         0               0  ...                1.00
# 126214              0    0         0               0  ...                1.00
# ...               ...  ...       ...             ...  ...                 ...
# 148440              0    0         0               0  ...                0.05
# 148458              0    0         0               0  ...                1.00
# 148501              0    0         0               0  ...                1.00
# 148511              0    0         0               0  ...                1.00
# 148515              0    0         0               0  ...                0.99
#
#         dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# 126081                0.05                    0.00                    0.00
# 126139                0.07                    0.00                    0.00
# 126154                0.00                    0.01                    0.00
# 126208                0.00                    1.00                    0.51
# 126214                0.01                    0.01                    0.00
# ...                    ...                     ...                     ...
# 148440                0.08                    0.00                    0.00
# 148458                0.00                    1.00                    0.00
# 148501                0.00                    1.00                    0.00
# 148511                0.00                    1.00                    0.00
# 148515                0.01                    0.00                    0.00
#
#         dsthostserrorrate  dsthostsrvserrorrate  dsthostrerrorrate  \
# 126081                0.0                   0.0                1.0
# 126139                1.0                   1.0                0.0
# 126154                0.0                   0.0                0.0
# 126208                0.0                   0.0                0.0
# 126214                0.0                   0.0                0.0
# ...                   ...                   ...                ...
# 148440                1.0                   1.0                0.0
# 148458                0.0                   0.0                0.0
# 148501                0.0                   0.0                0.0
# 148511                0.0                   0.0                0.0
# 148515                0.0                   0.0                0.0
#
#         dsthostsrvrerrorrate   attack  lastflag
# 126081                   1.0  neptune        21
# 126139                   0.0  neptune        21
# 126154                   0.0   normal        18
# 126208                   0.0      pod        15
# 126214                   0.0   normal        18
# ...                      ...      ...       ...
# 148440                   0.0  neptune        21
# 148458                   0.0    smurf        20
# 148501                   0.0    smurf        19
# 148511                   0.0    smurf        20
# 148515                   0.0   normal        21
#
# [610 rows x 38 columns]

# %%
Net_data_new=Net_data_new.loc[~Net_data_new.duplicated()]

# %%
Net_data_new.shape
# Out:
# (147907, 38)

# %%
Net_data_new['attack'].loc[Net_data_new['attack']!='normal']='attack'

# %%
Obj_col=Net_data_new.select_dtypes(include='object').columns
print(Obj_col)
# Out:
# Index(['protocoltype', 'service', 'flag', 'attack'], dtype='object')

# %%
le=LabelEncoder()
for i in Obj_col:
    Net_data_new[i]=le.fit_transform(Net_data_new[i])

# %%
X=Net_data_new.drop(['attack'],axis=1)
y=Net_data_new['attack']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (103534, 37)
# (44373, 37)

# %%
rf=RandomForestClassifier(n_estimators=100)
rf.fit(X_train,y_train)
y_pred=rf.predict(X_test)
rf_score=rf.score(X_test,y_test)*100
print(rf_score)
# Out:
# 99.93013769634688

# %%
acc_score=accuracy_score(y_test,y_pred)
print(acc_score*100)
# Out:
# 99.93013769634688
